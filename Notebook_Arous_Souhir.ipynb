# %% [markdown]
# ### Decision Making Problem :
#
# #### Choosing the best hotel to stay in.
#
# Source of dataset :  https://www.kaggle.com/harikrishna9/hotel-feed-back-data

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("Sample_hotel_data.csv")

df
# Out:
#                                  Hotel_Name_City  Review_Overall_Rating  \
# 0                            Bombay Hotel Jaipur                      3
# 1                            Bombay Hotel Jaipur                      1
# 2          Coffea Aroma Resort - Wayanad Meppadi                      2
# 3          Coffea Aroma Resort - Wayanad Meppadi                      3
# 4          Coffea Aroma Resort - Wayanad Meppadi                      3
# ..                                           ...                    ...
# 937                 Trishul Hotel Tiruvannamalai                      4
# 938                 Trishul Hotel Tiruvannamalai                      4
# 939  Urumbi Hill Palace Plantation Resort Idukki                      4
# 940  Urumbi Hill Palace Plantation Resort Idukki                      5
# 941  Urumbi Hill Palace Plantation Resort Idukki                      5
#
#     date_of_review Month_of_Visit   Review_Type  Rating_Value  \
# ...

# %%
df.shape
# Out:
# (942, 11)

# %% [markdown]
# #### We need to make sure there is no empty cells

# %%
df=df.dropna()
df
# Out:
#                                  Hotel_Name_City  Review_Overall_Rating  \
# 7          Coffea Aroma Resort - Wayanad Meppadi                      4
# 8          Coffea Aroma Resort - Wayanad Meppadi                      5
# 9          Coffea Aroma Resort - Wayanad Meppadi                      4
# 10         Coffea Aroma Resort - Wayanad Meppadi                      4
# 11         Coffea Aroma Resort - Wayanad Meppadi                      5
# ..                                           ...                    ...
# 936                 Trishul Hotel Tiruvannamalai                      5
# 937                 Trishul Hotel Tiruvannamalai                      4
# 938                 Trishul Hotel Tiruvannamalai                      4
# 939  Urumbi Hill Palace Plantation Resort Idukki                      4
# 940  Urumbi Hill Palace Plantation Resort Idukki                      5
#
#     date_of_review Month_of_Visit  Review_Type  Rating_Value  Rating_Location  \
# ...

# %%
df.columns
# Out:
# Index(['Hotel_Name_City', 'Review_Overall_Rating', 'date_of_review',
#        'Month_of_Visit', 'Review_Type', 'Rating_Value', 'Rating_Location',
#        'Rating_Sleep_Quality', 'Rating_Rooms', 'Rating_Cleanliness',
#        'Rating_Service'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Hotel_Name_City           object
# Review_Overall_Rating      int64
# date_of_review            object
# Month_of_Visit            object
# Review_Type               object
# Rating_Value             float64
# Rating_Location          float64
# Rating_Sleep_Quality     float64
# Rating_Rooms             float64
# Rating_Cleanliness       float64
# Rating_Service           float64
# dtype: object

# %% [markdown]
# #### After familiarization with the dataset, we can now choose the criteria we will be working on
#
# I chose to delete 'Review_Overall_Rating','date_of_review','Month_of_Visit' and 'Review_Type' because of their uselessness

# %%
df.drop(['Review_Overall_Rating','date_of_review','Month_of_Visit','Review_Type'], inplace=True, axis=1)

df.columns
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Index(['Hotel_Name_City', 'Rating_Value', 'Rating_Location',
#        'Rating_Sleep_Quality', 'Rating_Rooms', 'Rating_Cleanliness',
#        'Rating_Service'],
#       dtype='object')

# %% [markdown]
# ##### We now have 6 Criteria : C1-Rating Value, C2-Rating Location, C3-Rating Sleep Quality, C4-Rating Rooms, C5-Rating Cleanliness, C6-Rating Service
# ##### I will define the weights (it is a personal choice) and our goal is to maximize each criterion

# %%
df['Hotel_Name_City'].nunique()
# Out:
# 21

# %% [markdown]
# #### There are 21 hotels rated in the dataset, for academic and optimization reasons, I chose to keep 5 hotels.
# ##### It means we will have 5 alternatives :
#
# ##### A1-Coffea Aroma Resort, A2-Costa Malabari Kannur, A3-Hotel Shreenath Palace Jaisalmer, A4-Ravine Hotel Satara, A5-Midtown Hotel Haridwar.

# %%
s_Rating_Value =0.0
s_Rating_Location =0
s_Rating_Sleep_Quality =0
s_Rating_Rooms =0
s_Rating_Cleanliness =0
s_Rating_Service =0

nb_Rating_Value =0
nb_Rating_Location =0
nb_Rating_Sleep_Quality =0
nb_Rating_Rooms =0
nb_Rating_Cleanliness =0
nb_Rating_Service =0

for i in range(len(df)):
    if df.iloc[i,0] == "Coffea Aroma Resort - Wayanad Meppadi" :
        
        s_Rating_Value += df.iloc[i,1]
        s_Rating_Location += df.iloc[i,2]
        s_Rating_Sleep_Quality += df.iloc[i,3]
        s_Rating_Rooms += df.iloc[i,4]
        s_Rating_Cleanliness += df.iloc[i,5]
        s_Rating_Service += df.iloc[i,6]
        
        nb_Rating_Value +=1
        nb_Rating_Location +=1
        nb_Rating_Sleep_Quality +=1
        nb_Rating_Rooms +=1
        nb_Rating_Cleanliness +=1
        nb_Rating_Service +=1
        
data = {'C1-Rating Value': s_Rating_Value/nb_Rating_Value,
        'C2-Rating Location': s_Rating_Location/nb_Rating_Location,
        'C3-Rating Sleep Quality': s_Rating_Sleep_Quality/nb_Rating_Sleep_Quality,
        'C4-Rating Rooms': s_Rating_Rooms/nb_Rating_Rooms,
        'C5-Rating Cleanliness': s_Rating_Cleanliness/nb_Rating_Cleanliness,
        'C6-Rating Service': s_Rating_Service/nb_Rating_Service
        }

t = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                              'Max', 'Min', 'Weights', 'Sum'])

s_Rating_Value =0.0
s_Rating_Location =0
s_Rating_Sleep_Quality =0
s_Rating_Rooms =0
s_Rating_Cleanliness =0
s_Rating_Service =0

nb_Rating_Value =0
nb_Rating_Location =0
nb_Rating_Sleep_Quality =0
nb_Rating_Rooms =0
nb_Rating_Cleanliness =0
nb_Rating_Service =0

for i in range(len(df)):
    if df.iloc[i,0] == "Costa Malabari Kannur" :
        
        s_Rating_Value += df.iloc[i,1]
        s_Rating_Location += df.iloc[i,2]
        s_Rating_Sleep_Quality += df.iloc[i,3]
        s_Rating_Rooms += df.iloc[i,4]
        s_Rating_Cleanliness += df.iloc[i,5]
        s_Rating_Service += df.iloc[i,6]
        
        nb_Rating_Value +=1
        nb_Rating_Location +=1
        nb_Rating_Sleep_Quality +=1
        nb_Rating_Rooms +=1
        nb_Rating_Cleanliness +=1
        nb_Rating_Service +=1

t.iloc[1,0]= s_Rating_Value/nb_Rating_Value
t.iloc[1,1]= s_Rating_Location/nb_Rating_Location
t.iloc[1,2]= s_Rating_Sleep_Quality/nb_Rating_Sleep_Quality
t.iloc[1,3]= s_Rating_Rooms/nb_Rating_Rooms
t.iloc[1,4]= s_Rating_Cleanliness/nb_Rating_Cleanliness
t.iloc[1,5]= s_Rating_Service/nb_Rating_Service

s_Rating_Value =0.0
s_Rating_Location =0
s_Rating_Sleep_Quality =0
s_Rating_Rooms =0
s_Rating_Cleanliness =0
s_Rating_Service =0

nb_Rating_Value =0
nb_Rating_Location =0
nb_Rating_Sleep_Quality =0
nb_Rating_Rooms =0
nb_Rating_Cleanliness =0
nb_Rating_Service =0

for i in range(len(df)):
    if df.iloc[i,0] == "Hotel Shreenath Palace Jaisalmer" :
        
        s_Rating_Value += df.iloc[i,1]
        s_Rating_Location += df.iloc[i,2]
        s_Rating_Sleep_Quality += df.iloc[i,3]
        s_Rating_Rooms += df.iloc[i,4]
        s_Rating_Cleanliness += df.iloc[i,5]
        s_Rating_Service += df.iloc[i,6]
        
        nb_Rating_Value +=1
        nb_Rating_Location +=1
        nb_Rating_Sleep_Quality +=1
        nb_Rating_Rooms +=1
        nb_Rating_Cleanliness +=1
        nb_Rating_Service +=1

t.iloc[2,0]= s_Rating_Value/nb_Rating_Value
t.iloc[2,1]= s_Rating_Location/nb_Rating_Location
t.iloc[2,2]= s_Rating_Sleep_Quality/nb_Rating_Sleep_Quality
t.iloc[2,3]= s_Rating_Rooms/nb_Rating_Rooms
t.iloc[2,4]= s_Rating_Cleanliness/nb_Rating_Cleanliness
t.iloc[2,5]= s_Rating_Service/nb_Rating_Service

s_Rating_Value =0.0
s_Rating_Location =0
s_Rating_Sleep_Quality =0
s_Rating_Rooms =0
s_Rating_Cleanliness =0
s_Rating_Service =0

nb_Rating_Value =0
nb_Rating_Location =0
nb_Rating_Sleep_Quality =0
nb_Rating_Rooms =0
nb_Rating_Cleanliness =0
nb_Rating_Service =0

for i in range(len(df)):
    if df.iloc[i,0] == "Ravine Hotel Satara" :
        
        s_Rating_Value += df.iloc[i,1]
        s_Rating_Location += df.iloc[i,2]
        s_Rating_Sleep_Quality += df.iloc[i,3]
        s_Rating_Rooms += df.iloc[i,4]
        s_Rating_Cleanliness += df.iloc[i,5]
        s_Rating_Service += df.iloc[i,6]
        
        nb_Rating_Value +=1
        nb_Rating_Location +=1
        nb_Rating_Sleep_Quality +=1
        nb_Rating_Rooms +=1
        nb_Rating_Cleanliness +=1
        nb_Rating_Service +=1

t.iloc[3,0]= s_Rating_Value/nb_Rating_Value
t.iloc[3,1]= s_Rating_Location/nb_Rating_Location
t.iloc[3,2]= s_Rating_Sleep_Quality/nb_Rating_Sleep_Quality
t.iloc[3,3]= s_Rating_Rooms/nb_Rating_Rooms
t.iloc[3,4]= s_Rating_Cleanliness/nb_Rating_Cleanliness
t.iloc[3,5]= s_Rating_Service/nb_Rating_Service

s_Rating_Value =0.0
s_Rating_Location =0
s_Rating_Sleep_Quality =0
s_Rating_Rooms =0
s_Rating_Cleanliness =0
s_Rating_Service =0

nb_Rating_Value =0
nb_Rating_Location =0
nb_Rating_Sleep_Quality =0
nb_Rating_Rooms =0
nb_Rating_Cleanliness =0
nb_Rating_Service =0

for i in range(len(df)):
    if df.iloc[i,0] == "Midtown Hotel Haridwar" :
        
        s_Rating_Value += df.iloc[i,1]
        s_Rating_Location += df.iloc[i,2]
        s_Rating_Sleep_Quality += df.iloc[i,3]
        s_Rating_Rooms += df.iloc[i,4]
        s_Rating_Cleanliness += df.iloc[i,5]
        s_Rating_Service += df.iloc[i,6]
        
        nb_Rating_Value +=1
        nb_Rating_Location +=1
        nb_Rating_Sleep_Quality +=1
        nb_Rating_Rooms +=1
        nb_Rating_Cleanliness +=1
        nb_Rating_Service +=1

t.iloc[4,0]= s_Rating_Value/nb_Rating_Value
t.iloc[4,1]= s_Rating_Location/nb_Rating_Location
t.iloc[4,2]= s_Rating_Sleep_Quality/nb_Rating_Sleep_Quality
t.iloc[4,3]= s_Rating_Rooms/nb_Rating_Rooms
t.iloc[4,4]= s_Rating_Cleanliness/nb_Rating_Cleanliness
t.iloc[4,5]= s_Rating_Service/nb_Rating_Service

#MIN MAX ROWS :

list = t.iloc[:5,0]
t.iloc[5,0]= list.max()
t.iloc[6,0]= list.min()

list = t.iloc[:5,1]
t.iloc[5,1]= list.max()
t.iloc[6,1]= list.min()

list = t.iloc[:5,2]
t.iloc[5,2]= list.max()
t.iloc[6,2]= list.min()

list = t.iloc[:5,3]
t.iloc[5,3]= list.max()
t.iloc[6,3]= list.min()

list = t.iloc[:5,4]
t.iloc[5,4]= list.max()
t.iloc[6,4]= list.min()

list = t.iloc[:5,5]
t.iloc[5,5]= list.max()
t.iloc[6,5]= list.min()

#CRITERIA WEIGHTS ROW :

t.iloc[7,:]= [0.2, 0.2, 0.1, 0.1, 0.2, 0.2] #These values are a personal choice, Therefore we need to have the sum of total weights = 1

#SUM ROW

t.iloc[8,0]= t.iloc[:5,0].sum()

t.iloc[8,1]= t.iloc[:5,1].sum()

t.iloc[8,2]= t.iloc[:5,2].sum()

t.iloc[8,3]= t.iloc[:5,3].sum()

t.iloc[8,4]= t.iloc[:5,4].sum()

t.iloc[8,5]= t.iloc[:5,5].sum()


t
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      4.266667            4.533333
# A2-Costa Malabari Kannur                    4.200000            4.418182
# A3-Hotel Shreenath Palace Jaisalmer         4.523810            4.777778
# A4-Ravine Hotel Satara                      3.781250            4.691964
# A5-Midtown Hotel Haridwar                   3.777778            4.000000
# Max                                         4.523810            4.777778
# Min                                         3.777778            4.000000
# Weights                                     0.200000            0.200000
# Sum                                        20.549504           22.421257
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              4.066667         3.888889
# A2-Costa Malabari Kannur                            4.381818         3.909091
# ...

# %%
t1 = t.iloc[:5,:6]
t1
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      4.266667            4.533333
# A2-Costa Malabari Kannur                    4.200000            4.418182
# A3-Hotel Shreenath Palace Jaisalmer         4.523810            4.777778
# A4-Ravine Hotel Satara                      3.781250            4.691964
# A5-Midtown Hotel Haridwar                   3.777778            4.000000
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              4.066667         3.888889
# A2-Costa Malabari Kannur                            4.381818         3.909091
# A3-Hotel Shreenath Palace Jaisalmer                 4.095238         4.603175
# A4-Ravine Hotel Satara                              3.857143         3.995536
# A5-Midtown Hotel Haridwar                           3.500000         3.611111
#
# ...

# %% [markdown]
# # Entropy

# %% [markdown]
# 1- Normalization:  p_ij = x_ij/sum{j}(x_ij)

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0}
t2 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                               'Sum'])
for i in range(6):
    for j in range(5):
        t2.iloc[j,i]= t.iloc[j,i]/t.iloc[8,i]
        
#t.iloc[8,:] represents the sum row      
        
t2.iloc[5,0]= t2.iloc[:5,0].sum()
t2.iloc[5,1]= t2.iloc[:5,1].sum()
t2.iloc[5,2]= t2.iloc[:5,2].sum()
t2.iloc[5,3]= t2.iloc[:5,3].sum()
t2.iloc[5,4]= t2.iloc[:5,4].sum()
t2.iloc[5,5]= t2.iloc[:5,5].sum()

t2
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      0.207629            0.202189
# A2-Costa Malabari Kannur                    0.204384            0.197053
# A3-Hotel Shreenath Palace Jaisalmer         0.220142            0.213091
# A4-Ravine Hotel Satara                      0.184007            0.209264
# A5-Midtown Hotel Haridwar                   0.183838            0.178402
# Sum                                         1.000000            1.000000
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.204346         0.194369
# A2-Costa Malabari Kannur                            0.220182         0.195378
# A3-Hotel Shreenath Palace Jaisalmer                 0.205782         0.230069
# A4-Ravine Hotel Satara                              0.193818         0.199699
# ...

# %% [markdown]
# 2- Entropy: e_j = -k * p_ij * ln(p_ij)

# %%
k= 1/np.log(5)
k
# Out:
# 0.6213349345596119

# %%
#p_ij*ln(p_ij)

for i in range(6):
    for j in range(5):
        t2.iloc[j,i]= t2.iloc[j,i]* np.log(t2.iloc[j,i])
        
t2.iloc[5,0]= t2.iloc[:5,0].sum()
t2.iloc[5,1]= t2.iloc[:5,1].sum()
t2.iloc[5,2]= t2.iloc[:5,2].sum()
t2.iloc[5,3]= t2.iloc[:5,3].sum()
t2.iloc[5,4]= t2.iloc[:5,4].sum()
t2.iloc[5,5]= t2.iloc[:5,5].sum()

t2
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                     -0.326393           -0.323210
# A2-Costa Malabari Kannur                   -0.324512           -0.320070
# A3-Hotel Shreenath Palace Jaisalmer        -0.333181           -0.329447
# A4-Ravine Hotel Satara                     -0.311484           -0.327322
# A5-Midtown Hotel Haridwar                  -0.311366           -0.307514
# Sum                                        -1.606936           -1.607563
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                             -0.324489        -0.318376
# A2-Costa Malabari Kannur                           -0.333202        -0.319017
# A3-Hotel Shreenath Palace Jaisalmer                -0.325329        -0.338058
# A4-Ravine Hotel Satara                             -0.318023        -0.321704
# ...

# %%
data = {'C1-Rating Value': [0],  'C2-Rating Location': [0], 'C3-Rating Sleep Quality': [0],  'C4-Rating Rooms': [0], 'C5-Rating Cleanliness': [0],'C6-Rating Service': [0]}
t3 = pd.DataFrame(data)

for i in range(6):
    t3.iloc[0,i]= t2.iloc[5,i] * k * (-1)
t3
# Out:
#    C1-Rating Value  C2-Rating Location  C3-Rating Sleep Quality  \
# 0         0.998446            0.998835                 0.998304
#
#    C4-Rating Rooms  C5-Rating Cleanliness  C6-Rating Service
# 0         0.997966               0.998722           0.996342

# %%
#1-e_j

for i in range(6):
    t3.iloc[0,i]= 1- t3.iloc[0,i]
t3
# Out:
#    C1-Rating Value  C2-Rating Location  C3-Rating Sleep Quality  \
# 0         0.001554            0.001165                 0.001696
#
#    C4-Rating Rooms  C5-Rating Cleanliness  C6-Rating Service
# 0         0.002034               0.001278           0.003658

# %%
sum = t3.iloc[0,:].sum()
    
print("Sum = " + str(sum))
# Out:
# Sum = 0.0113856320572151

# %% [markdown]
# 3- w_j = 1-e_j / sum(1-e_j)

# %%
for i in range(6):
    t3.iloc[0,i]= t3.iloc[0,i] / sum
t3
# Out:
#    C1-Rating Value  C2-Rating Location  C3-Rating Sleep Quality  \
# 0         0.136527            0.102325                 0.148963
#
#    C4-Rating Rooms  C5-Rating Cleanliness  C6-Rating Service
# 0         0.178648               0.112223           0.321314

# %%
list_cr = t3.iloc[0,:]

list_cr=list_cr.sort_values(ascending=False)

print("RANK : ")
list_cr
# Out:
# RANK :
# C6-Rating Service          0.321314
# C4-Rating Rooms            0.178648
# C3-Rating Sleep Quality    0.148963
# C1-Rating Value            0.136527
# C5-Rating Cleanliness      0.112223
# C2-Rating Location         0.102325
# Name: 0, dtype: float64

# %% [markdown]
# # WSM + WPM + WASPASS

# %% [markdown]
# 1- Normalization: [MAX] p_ij = x_ij/max{j}(x_ij) - [MIN] min{j}{x_ij}/x_ij

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0}
t2 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                               'Sum'])
for i in range(6):
    for j in range(5):
        t2.iloc[j,i]= t.iloc[j,i]/t.iloc[5,i]
        
#t.iloc[5,:] represents the max row  
        
t2.iloc[5,0]= t2.iloc[:5,0].sum()
t2.iloc[5,1]= t2.iloc[:5,1].sum()
t2.iloc[5,2]= t2.iloc[:5,2].sum()
t2.iloc[5,3]= t2.iloc[:5,3].sum()
t2.iloc[5,4]= t2.iloc[:5,4].sum()
t2.iloc[5,5]= t2.iloc[:5,5].sum()

t2
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      0.943158            0.948837
# A2-Costa Malabari Kannur                    0.928421            0.924736
# A3-Hotel Shreenath Palace Jaisalmer         1.000000            1.000000
# A4-Ravine Hotel Satara                      0.835855            0.982039
# A5-Midtown Hotel Haridwar                   0.835088            0.837209
# Sum                                         4.542522            4.692821
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.928077         0.844828
# A2-Costa Malabari Kannur                            1.000000         0.849216
# A3-Hotel Shreenath Palace Jaisalmer                 0.934598         1.000000
# A4-Ravine Hotel Satara                              0.880261         0.867996
# ...

# %% [markdown]
# # WSM or Simple Additive Weighting(SAW) method

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0,
             'Sum': 0}
t3 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar'])

for i in range(6):
    for j in range(5):
        t3.iloc[j,i]= t2.iloc[j,i] * t.iloc[7,i]
        
#t.iloc[7,:] represents the criteria weights row  
        
t3.iloc[0,6]= t3.iloc[0,:6].sum()
t3.iloc[1,6]= t3.iloc[1,:6].sum()
t3.iloc[2,6]= t3.iloc[2,:6].sum()
t3.iloc[3,6]= t3.iloc[3,:6].sum()
t3.iloc[4,6]= t3.iloc[4,:6].sum()

t3
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      0.188632            0.189767
# A2-Costa Malabari Kannur                    0.185684            0.184947
# A3-Hotel Shreenath Palace Jaisalmer         0.200000            0.200000
# A4-Ravine Hotel Satara                      0.167171            0.196408
# A5-Midtown Hotel Haridwar                   0.167018            0.167442
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.092808         0.084483
# A2-Costa Malabari Kannur                            0.100000         0.084922
# A3-Hotel Shreenath Palace Jaisalmer                 0.093460         0.100000
# A4-Ravine Hotel Satara                              0.088026         0.086800
# A5-Midtown Hotel Haridwar                           0.079876         0.078448
#
# ...

# %%
list_alternatives = t3.iloc[:,6]

list_alternatives=list_alternatives.sort_values(ascending=False)

print("RANK : ")
list_alternatives
# Out:
# RANK :
# A3-Hotel Shreenath Palace Jaisalmer    0.989428
# A2-Costa Malabari Kannur               0.945437
# A1-Coffea Aroma Resort                 0.916681
# A4-Ravine Hotel Satara                 0.867077
# A5-Midtown Hotel Haridwar              0.817770
# Name: Sum, dtype: float64

# %% [markdown]
# #  WPM

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0,
             'Product': 0}
t3 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar'])

for i in range(6):
    for j in range(5):
        t3.iloc[j,i]= pow(t2.iloc[j,i],t.iloc[7,i])
        
t3.iloc[0,6]= np.prod(t3.iloc[0,:6])
t3.iloc[1,6]= np.prod(t3.iloc[1,:6])
t3.iloc[2,6]= np.prod(t3.iloc[2,:6])
t3.iloc[3,6]= np.prod(t3.iloc[3,:6])
t3.iloc[4,6]= np.prod(t3.iloc[4,:6])

t3
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      0.988364            0.989551
# A2-Costa Malabari Kannur                    0.985256            0.984472
# A3-Hotel Shreenath Palace Jaisalmer         1.000000            1.000000
# A4-Ravine Hotel Satara                      0.964775            0.996382
# A5-Midtown Hotel Haridwar                   0.964598            0.965088
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.992564         0.983279
# A2-Costa Malabari Kannur                            1.000000         0.983789
# A3-Hotel Shreenath Palace Jaisalmer                 0.993259         1.000000
# A4-Ravine Hotel Satara                              0.987327         0.985943
# A5-Midtown Hotel Haridwar                           0.977780         0.976019
#
# ...

# %%
list_alternatives2 = t3.iloc[:,6]

list_alternatives2=list_alternatives2.sort_values(ascending=False)

print("RANK : ")
list_alternatives2
# Out:
# RANK :
# A3-Hotel Shreenath Palace Jaisalmer    0.989222
# A2-Costa Malabari Kannur               0.944378
# A1-Coffea Aroma Resort                 0.916141
# A4-Ravine Hotel Satara                 0.863750
# A5-Midtown Hotel Haridwar              0.817428
# Name: Product, dtype: float64

# %% [markdown]
# # WASPASS

# %%
lambd = 0.5
Q = []

for i in range(5):
    Q.append(lambd * list_alternatives[i] + (1-lambd) * list_alternatives2[i] )
    
#list_alternatives : result of WSM method
#list_alternatives2 : result of WPM method

print("Q_i : ")
Q
# Out:
# Q_i :
# [0.98932472762392,
#  0.9449077531830232,
#  0.9164110523924061,
#  0.8654134624313213,
#  0.817598827553728]

# %% [markdown]
# # TOPSIS

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0}
t2 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                               'Sum', 'SQRT(Sum(x_ij^2))'])
for i in range(6):
    for j in range(5):
        t2.iloc[j,i]= t.iloc[j,i]
        
t2.iloc[5,0]= t.iloc[8,0]
t2.iloc[5,1]= t.iloc[8,1]
t2.iloc[5,2]= t.iloc[8,2]
t2.iloc[5,3]= t.iloc[8,3]
t2.iloc[5,4]= t.iloc[8,4]
t2.iloc[5,5]= t.iloc[8,5]

#t.iloc[8,:] represents the sum row

for i in range(6):
    sum=0
    
    for j in range(5):
        sum += t.iloc[j,i] **2
    
    t2.iloc[6,i] = np.sqrt( sum )

t2
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      4.266667            4.533333
# A2-Costa Malabari Kannur                    4.200000            4.418182
# A3-Hotel Shreenath Palace Jaisalmer         4.523810            4.777778
# A4-Ravine Hotel Satara                      3.781250            4.691964
# A5-Midtown Hotel Haridwar                   3.777778            4.000000
# Sum                                        20.549504           22.421257
# SQRT(Sum(x_ij^2))                           9.212967           10.045553
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              4.066667         3.888889
# A2-Costa Malabari Kannur                            4.381818         3.909091
# A3-Hotel Shreenath Palace Jaisalmer                 4.095238         4.603175
# ...

# %% [markdown]
# 1- Normalization: r_ij

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0}
t3 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                               'Sum'])
for i in range(6):
    for j in range(5):
        t3.iloc[j,i]= t2.iloc[j,i] / t2.iloc[6,i]

t3.iloc[5,0]= t3.iloc[:5,0].sum()
t3.iloc[5,1]= t3.iloc[:5,1].sum()
t3.iloc[5,2]= t3.iloc[:5,2].sum()
t3.iloc[5,3]= t3.iloc[:5,3].sum()
t3.iloc[5,4]= t3.iloc[:5,4].sum()
t3.iloc[5,5]= t3.iloc[:5,5].sum()


t3
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      0.463115            0.451278
# A2-Costa Malabari Kannur                    0.455879            0.439815
# A3-Hotel Shreenath Palace Jaisalmer         0.491026            0.475611
# A4-Ravine Hotel Satara                      0.410427            0.467069
# A5-Midtown Hotel Haridwar                   0.410050            0.398186
# Sum                                         2.230498            2.231959
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.455703         0.433175
# A2-Costa Malabari Kannur                            0.491019         0.435425
# A3-Hotel Shreenath Palace Jaisalmer                 0.458905         0.512737
# A4-Ravine Hotel Satara                              0.432224         0.445054
# ...

# %% [markdown]
# 2- v_ij = r_ij*w_ij

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0}
t4 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar'])

for i in range(6):
    for j in range(5):
        t4.iloc[j,i]= t3.iloc[j,i] * t.iloc[7,i]
        
#t.iloc[7,:] represents the criteria weights row 

t4
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      0.092623            0.090256
# A2-Costa Malabari Kannur                    0.091176            0.087963
# A3-Hotel Shreenath Palace Jaisalmer         0.098205            0.095122
# A4-Ravine Hotel Satara                      0.082085            0.093414
# A5-Midtown Hotel Haridwar                   0.082010            0.079637
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.045570         0.043317
# A2-Costa Malabari Kannur                            0.049102         0.043543
# A3-Hotel Shreenath Palace Jaisalmer                 0.045890         0.051274
# A4-Ravine Hotel Satara                              0.043222         0.044505
# A5-Midtown Hotel Haridwar                           0.039220         0.040223
#
# ...

# %% [markdown]
# 3- V_j+ and V_j-

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0}
t5 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                               'Max', 'Min', 'v_j +', 'v_j -'])

for i in range(6):
    for j in range(5):
        t5.iloc[j,i]= t4.iloc[j,i]
                               
                               
t5.iloc[5,0]= t5.iloc[:5,0].max()
t5.iloc[5,1]= t5.iloc[:5,1].max()
t5.iloc[5,2]= t5.iloc[:5,2].max()
t5.iloc[5,3]= t5.iloc[:5,3].max()
t5.iloc[5,4]= t5.iloc[:5,4].max()
t5.iloc[5,5]= t5.iloc[:5,5].max()
                             
t5.iloc[6,0]= t5.iloc[:5,0].min()
t5.iloc[6,1]= t5.iloc[:5,1].min()
t5.iloc[6,2]= t5.iloc[:5,2].min()
t5.iloc[6,3]= t5.iloc[:5,3].min()
t5.iloc[6,4]= t5.iloc[:5,4].min()
t5.iloc[6,5]= t5.iloc[:5,5].min()

# We're searching for maximization for all our criterias, for this reason v_j+ = Max and v_j- = Min 
# If we had a criterion with minimization we would have had v_j- = Max and v_j+ = Min 
# We don't have such case in our example

t5.iloc[7,0]= t5.iloc[5,0]
t5.iloc[7,1]= t5.iloc[5,1]
t5.iloc[7,2]= t5.iloc[5,2]
t5.iloc[7,3]= t5.iloc[5,3]
t5.iloc[7,4]= t5.iloc[5,4]
t5.iloc[7,5]= t5.iloc[5,5]

t5.iloc[8,0]= t5.iloc[6,0]
t5.iloc[8,1]= t5.iloc[6,1]
t5.iloc[8,2]= t5.iloc[6,2]
t5.iloc[8,3]= t5.iloc[6,3]
t5.iloc[8,4]= t5.iloc[6,4]
t5.iloc[8,5]= t5.iloc[6,5]
                              
t5
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      0.092623            0.090256
# A2-Costa Malabari Kannur                    0.091176            0.087963
# A3-Hotel Shreenath Palace Jaisalmer         0.098205            0.095122
# A4-Ravine Hotel Satara                      0.082085            0.093414
# A5-Midtown Hotel Haridwar                   0.082010            0.079637
# Max                                         0.098205            0.095122
# Min                                         0.082010            0.079637
# v_j +                                       0.098205            0.095122
# v_j -                                       0.082010            0.079637
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.045570         0.043317
# A2-Costa Malabari Kannur                            0.049102         0.043543
# ...

# %% [markdown]
# 4.1- SQR(v_ij - v_j+)

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0,
       'Sum' : 0, 'S_i +' : 0}
t6 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                               ])

for i in range(6):
    for j in range(5):
        t6.iloc[j,i]= ( t5.iloc[j,i] - t5.iloc[7,i] ) **2

t6.iloc[0,6]= t6.iloc[0,:6].sum()
t6.iloc[1,6]= t6.iloc[1,:6].sum()
t6.iloc[2,6]= t6.iloc[2,:6].sum()
t6.iloc[3,6]= t6.iloc[3,:6].sum()
t6.iloc[4,6]= t6.iloc[4,:6].sum()

t6.iloc[0,7]= np.sqrt(t6.iloc[0,6])
t6.iloc[1,7]= np.sqrt(t6.iloc[1,6])
t6.iloc[2,7]= np.sqrt(t6.iloc[2,6])
t6.iloc[3,7]= np.sqrt(t6.iloc[3,6])
t6.iloc[4,7]= np.sqrt(t6.iloc[4,6])

t6
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                      0.000031            0.000024
# A2-Costa Malabari Kannur                    0.000049            0.000051
# A3-Hotel Shreenath Palace Jaisalmer         0.000000            0.000000
# A4-Ravine Hotel Satara                      0.000260            0.000003
# A5-Midtown Hotel Haridwar                   0.000262            0.000240
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.000012         0.000063
# A2-Costa Malabari Kannur                            0.000000         0.000060
# A3-Hotel Shreenath Palace Jaisalmer                 0.000010         0.000000
# A4-Ravine Hotel Satara                              0.000035         0.000046
# A5-Midtown Hotel Haridwar                           0.000098         0.000122
#
# ...

# %% [markdown]
# 4.1- SQR(v_ij - v_j+)

# %%
data = {'C1-Rating Value': 0,  'C2-Rating Location': 0, 'C3-Rating Sleep Quality': 0,  'C4-Rating Rooms': 0, 'C5-Rating Cleanliness': 0,'C6-Rating Service': 0,
       'Sum' : 0, 'S_i -' : 0}
t7 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                               ])

for i in range(6):
    for j in range(5):
        t7.iloc[j,i]= ( t5.iloc[j,i] - t5.iloc[8,i] ) **2

t7.iloc[0,6]= t7.iloc[0,:6].sum()
t7.iloc[1,6]= t7.iloc[1,:6].sum()
t7.iloc[2,6]= t7.iloc[2,:6].sum()
t7.iloc[3,6]= t7.iloc[3,:6].sum()
t7.iloc[4,6]= t7.iloc[4,:6].sum()

t7.iloc[0,7]= np.sqrt(t7.iloc[0,6])
t7.iloc[1,7]= np.sqrt(t7.iloc[1,6])
t7.iloc[2,7]= np.sqrt(t7.iloc[2,6])
t7.iloc[3,7]= np.sqrt(t7.iloc[3,6])
t7.iloc[4,7]= np.sqrt(t7.iloc[4,6])

t7
# Out:
#                                      C1-Rating Value  C2-Rating Location  \
# A1-Coffea Aroma Resort                  1.126371e-04            0.000113
# A2-Costa Malabari Kannur                8.401236e-05            0.000069
# A3-Hotel Shreenath Palace Jaisalmer     2.622863e-04            0.000240
# A4-Ravine Hotel Satara                  5.681670e-09            0.000190
# A5-Midtown Hotel Haridwar               0.000000e+00            0.000000
#
#                                      C3-Rating Sleep Quality  C4-Rating Rooms  \
# A1-Coffea Aroma Resort                              0.000040         0.000010
# A2-Costa Malabari Kannur                            0.000098         0.000011
# A3-Hotel Shreenath Palace Jaisalmer                 0.000044         0.000122
# A4-Ravine Hotel Satara                              0.000016         0.000018
# A5-Midtown Hotel Haridwar                           0.000000         0.000000
#
# ...

# %%
data = {'S_i +': 0,  'S_i -': 0, 'Sum': 0, 'Pi' : 0}
t8 = pd.DataFrame(data, index=['A1-Coffea Aroma Resort','A2-Costa Malabari Kannur','A3-Hotel Shreenath Palace Jaisalmer', 'A4-Ravine Hotel Satara', 'A5-Midtown Hotel Haridwar',
                               ])

t8.iloc[:,0]= t6.iloc[:,7]
t8.iloc[:,1]= t7.iloc[:,7]

t8.iloc[0,2]= t8.iloc[0,0] + t8.iloc[0,1]
t8.iloc[1,2]= t8.iloc[1,0] + t8.iloc[1,1]
t8.iloc[2,2]= t8.iloc[2,0] + t8.iloc[2,1]
t8.iloc[3,2]= t8.iloc[3,0] + t8.iloc[3,1]
t8.iloc[4,2]= t8.iloc[4,0] + t8.iloc[4,1]

t8.iloc[0,3]= t8.iloc[0,1] / t8.iloc[0,2]
t8.iloc[1,3]= t8.iloc[1,1] / t8.iloc[1,2]
t8.iloc[2,3]= t8.iloc[2,1] / t8.iloc[2,2]
t8.iloc[3,3]= t8.iloc[3,1] / t8.iloc[3,2]
t8.iloc[4,3]= t8.iloc[4,1] / t8.iloc[4,2]

t8
# Out:
#                                         S_i +     S_i -       Sum        Pi
# A1-Coffea Aroma Resort               0.017853  0.023298  0.041151  0.566163
# A2-Costa Malabari Kannur             0.013666  0.030245  0.043911  0.688781
# A3-Hotel Shreenath Palace Jaisalmer  0.003756  0.038701  0.042457  0.911533
# A4-Ravine Hotel Satara               0.033034  0.015888  0.048921  0.324761
# A5-Midtown Hotel Haridwar            0.037866  0.003712  0.041578  0.089272

# %%
list_alternatives = t8.iloc[:,3]

list_alternatives=list_alternatives.sort_values(ascending=False)

print("RANK : ")
list_alternatives
# Out:
# RANK :
# A3-Hotel Shreenath Palace Jaisalmer    0.911533
# A2-Costa Malabari Kannur               0.688781
# A1-Coffea Aroma Resort                 0.566163
# A4-Ravine Hotel Satara                 0.324761
# A5-Midtown Hotel Haridwar              0.089272
# Name: Pi, dtype: float64
